# %% [markdown]
# # Import Libraries

# %%
try:
    import pandas as pd
    print("Imported Pandas")
except:
    print("Pandas not installed - installing pandas...")
    # !pip install pandas
    import pandas as pd
try:
    import plotly.express as px
    print("Imported Plotly")
except:
    print("Plotly not installed - installing plotly...")
    # !pip install plotly
    import plotly as px
# Out:
# Imported Pandas
# Imported Plotly

# %% [markdown]
# # Read CSV File
# - Check Parse Dates Argument
# - Enter header = 10 if header rows are included in file

# %%
df = pd.read_csv("C:/Users/chags/OneDrive/Documents/DoD/RawData/PIL01_CUET1_02082022_a2.csv", parse_dates = ['Timestamp'])
df
# Out:
#         Unnamed: 0  class anno_key               Timestamp  Accelerometer X  \
# 0                0      0        0 2021-11-15 13:20:00.000        -0.002930
# 1                1      0        0 2021-11-15 13:20:00.010        -0.002930
# 2                2      0        0 2021-11-15 13:20:00.020        -0.001465
# 3                3      0        0 2021-11-15 13:20:00.030        -0.001953
# 4                4      0        0 2021-11-15 13:20:00.040        -0.002930
# ...            ...    ...      ...                     ...              ...
# 164095      164095      0        0 2021-11-15 13:47:20.950        -0.059570
# 164096      164096      0        0 2021-11-15 13:47:20.960        -0.024414
# 164097      164097      0        0 2021-11-15 13:47:20.970        -0.008301
# 164098      164098      0        0 2021-11-15 13:47:20.980        -0.010742
# 164099      164099      0        0 2021-11-15 13:47:20.990        -0.004395
#
# ...

# %% [markdown]
# # Calculate Resultant and Plot Data Over Time

# %%
df["Resultant"] = (df['Accelerometer X']**2 + df['Accelerometer Y']**2 + df['Accelerometer Z']**2) / (1/2)
#px.scatter(df, x = "Timestamp", y = "Resultant", color = "Resultant")
